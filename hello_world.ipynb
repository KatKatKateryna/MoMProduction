# %%
print("Hello")
# Out:
# Hello

# %%
import gdal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import gdal
#
# ModuleNotFoundError: No module named 'gdal'
